# %% [markdown]
# * Usar la herramienta de Stellarium para saber con más precisión dónde va estar la luna y cuál va ser su intensidad en iluminación.
# * Usar Stellarium Desktop, porque la versión web tiene limitaciones. [Stellarium](https://stellarium.org/)
#
# * Determinar el ratio al cual varía la iluminación de la luna.
#
# * Ver guía de stellarium para el curso.

# %% [markdown]
# * Oblicuidad de la eclíptica
# * Ángulo de oblicuidad de la eclíptica: $\epsilon\sim 23.5°$
# * [Axial tilt](https://en.wikipedia.org/wiki/Axial_tilt)

# %% [markdown]
# * Explicación de como orientarse
# * Uso de gnomon para ver la sombra y usarla para orientarse
# * Uso del gnomon para determinar la latitud

# %% [markdown]
# * Los rayos del sol solamente van a ser perpendiculares a la tierra en la zona intertropical, en algun momento del año.
# * Hay dos días sin sombra al año para las zonas intertropicales
# * Cuántos días después de el día sin sombra en el ecuador, ocurrirá en medellín. Tenemos latitud $6.25°$

# %% [markdown]
# * Declinación y Ascención recta

# %% [markdown]
# Para la práctica de Eratóstenes:
#
# $$\tan{\phi} = \frac{a}{L}$$

# %% [markdown]
# Materiales para el experimento
#
# * Plomada para medir verticalidad
# * Un gnomon
# * Cinta métrica
# * Calculadora
# * Lápiz y papel

# %% [markdown]
# * La idea es hacer la práctica el día del equinoccio.
# * Leer la guía
# * Hacer varias medidas
# * Empezar antes del medio día y hasta después del medio día: Cada 2 minutos
# * Se puede hacer el 18, 19, 20, 21, 22
