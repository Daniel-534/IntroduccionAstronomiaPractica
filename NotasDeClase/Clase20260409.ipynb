# %% [markdown]
# Clase enfocada en Astronomía de posición.
#
# Para analizar el sol:
#
# * Eje del mundo
# * Polo norte celeste
# * Polo sur celeste
# * Latitud
# * Altura $h$
# * Culminación $h_max$
# * Declinación
# * Día sin sombra
# * $h_1 = 90° - \varphi + \delta_1$ -> si culmina al sur del cenit
# * $h_2 = 90° - \delta_2 + \varphi$ -> si culmina al norte del cenit
# * Con la altura del sol al medio día puedo saber la declinación
# * $\tan\left(\varphi - \delta\right) = \frac{s}{L}$
# * Cuidado con el signo de $\delta$ (si es positivo o negativo) ¿Al haber definido $h_1$ y $h_2$ aún debo tener cuidado con el signo de $\delta$?
# * Cuánto vale el ángulo horario en la culminación? -> 0

# %% [markdown]
# Tarea: Medir altura máxima y así cómo cambia la declinación. Es un experimento que se debe hacer todos los días
#
# Para estas fechas, tenemos $\delta = 90° + \varphi - h_{max}$

# %%
# Out:
# 1.5708 + DMSQuantity[{6., 15., 6.62}]

# %%
phi
# Out:
# 90 Degree + 22506.6 arcseconds
