# %% [markdown]
# # Coordenadas ecuatoriales

# %% [markdown]
# * Distancia de la luna al ecuador es la declinación
# * Ángulo horario; ángulo desde el meridiano al objeto, medido paralelo al ecuador. Sentido: hacia el occidente
# * Tiempo solar: $TS = H_{\odot} + 12h$
# * Podemos construír nuestro propio reloj solar

# %% [markdown]
# Hora $h_{\odot}$ $H_{\odot}$
