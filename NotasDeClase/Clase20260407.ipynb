# %% [markdown]
# * Para bibliografía: [Astrphysics Data system](https://ui.adsabs.harvard.edu/)
# * Resumen: Qué hizo, cómo lo hizo y qué obtuvo
# * Al final de la introducción debe haber un párrafo diciendo cómo está organizado el reporte
