# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Socialización sobre el trabajo de eratóstenes. Repaso de los materiales e indicaciones necesarias para el experimento.

# %% [markdown]
# * Usar hoja milimetrada -> marcar puntos y medir después
#
# * Coordenadas ecuatoriales horarias
#
# * Ver efemérides [JPL - NASA]("https://ssd.jpl.nasa.gov/horizons/app.html#/")
#
# * Usar Astroquery

# %% [markdown]
# * Propagación de errores
# * Desviación estándar y varianza
